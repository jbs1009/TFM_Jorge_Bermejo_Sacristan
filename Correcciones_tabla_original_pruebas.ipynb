# %%
# pip install mygene

# %%
import pandas as pd
import numpy as np
import requests
import time
import mygene

# %%
df = pd.read_csv("datosGene4PD/t_common_variant.txt", sep = "\t", index_col = False)

# %%
df.head(30)
# Out:
#    Chr      gene_symbol  SNPs_symbol SNP_position effect_allele  \
# 0    6           GPR126  rs757765789    142758601             T
# 1    1            SYT11  rs202015799    155839054             C
# 2   12          SLC2A13    rs1994090     40428561             G
# 3   12          SLC2A13    rs2708453     40478652             G
# 4   12          SLC2A13    rs4768212     40474147             C
# 5   14          SLC2A15    rs7304281     40465942             T
# 6   12  LINC02471;LRRK2    rs2046932     40580440             G
# 7   12            LRRK2    rs1491942     40620808             C
# 8   12            LRRK2   rs34637584     40734202             G
# 9    4      GPRIN3;SNCA     rs356220     90641340             T
# 10  18             MAPT    rs8070724     44081064             A
# 11  17  LINC02210-CRHR1    rs7215239     43767773             T
# 12   4      GPRIN3;SNCA     rs356220     90641340             T
# 13  17  LINC02210-CRHR1     rs417968     43728376             G
# ...
